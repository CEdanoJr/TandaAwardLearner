# %%
#Importing the packages or libraries to be use.
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Importing the data
data = pd.read_csv('/Users/celestinoedano/Desktop/timesheet data/casual.csv', names = ['f1','f2','f3','f4','f5','f6','f7'])

# %%
data
# Out:
#        f1  f2    f3    f4  f5    f6    f7
# 0    0.58   1   0.0  0.92   1  0.33  OT20
# 1    0.58   2   0.0  0.93   2  0.35  OT20
# 2    0.58   4   0.0  0.92   4  0.34  OT20
# 3    0.58   1   0.0  0.92   1  0.33  OT20
# 4    0.58   3   0.0  0.92   3  0.33  OT20
# 5    0.58   4   0.0  0.92   4  0.34  OT20
# 6    0.25   1  30.0  0.65   1  0.38  OT15
# 7    0.25   2  30.0  0.61   2  0.34  OT15
# 8    0.25   3  30.0  0.59   3  0.32  OT15
# 9    0.25   4  30.0  0.60   4  0.33  OT15
# 10   0.25   1  30.0  0.65   1  0.38  OT15
# 11   0.25   2  30.0  0.61   2  0.34  OT15
# 12   0.25   3  30.0  0.59   3  0.32  OT15
# 13   0.25   4  30.0  0.60   4  0.33  OT15
# 14   0.25   4  30.0  0.60   4  0.33  OT15
# 15   0.58   1   0.0  0.92   1  0.33  OT20
# 16   0.58   3   0.0  0.92   3  0.33  OT20
# 17   0.58   4   0.0  0.92   4  0.34  OT20
# 18   0.25   2  30.0  0.61   2  0.34  OT15
# 19   0.25   3  30.0  0.69   3  0.42  OT15
# 20   0.25   4  30.0  0.61   4  0.34  OT15
# ...

# %%
#Count the number of instances for each class (awards).
data["f7"].value_counts()
# Out:
# OT15    205
# OT20    194
# WK        6
# Name: f7, dtype: int64

# %%
#Statistical data visualization.
sns.FacetGrid(data, hue = "f7", size = 5) \
    .map(plt.scatter, "f1", "f4") \
    .add_legend()

# %%
#Map data into arrays. Also called One hot encoding.
ot15 = np.asarray([1,0,0])
ot20 = np.asarray([0,1,0])
wk = np.asarray([0,0,1])
data['f7'] = data['f7'].map({'OT15': ot15, 'OT20': ot20, 'WK': wk})

# %%
data
# Out:
#        f1  f2    f3    f4  f5    f6         f7
# 0    0.58   1   0.0  0.92   1  0.33  [0, 1, 0]
# 1    0.58   2   0.0  0.93   2  0.35  [0, 1, 0]
# 2    0.58   4   0.0  0.92   4  0.34  [0, 1, 0]
# 3    0.58   1   0.0  0.92   1  0.33  [0, 1, 0]
# 4    0.58   3   0.0  0.92   3  0.33  [0, 1, 0]
# 5    0.58   4   0.0  0.92   4  0.34  [0, 1, 0]
# 6    0.25   1  30.0  0.65   1  0.38  [1, 0, 0]
# 7    0.25   2  30.0  0.61   2  0.34  [1, 0, 0]
# 8    0.25   3  30.0  0.59   3  0.32  [1, 0, 0]
# 9    0.25   4  30.0  0.60   4  0.33  [1, 0, 0]
# 10   0.25   1  30.0  0.65   1  0.38  [1, 0, 0]
# 11   0.25   2  30.0  0.61   2  0.34  [1, 0, 0]
# 12   0.25   3  30.0  0.59   3  0.32  [1, 0, 0]
# 13   0.25   4  30.0  0.60   4  0.33  [1, 0, 0]
# 14   0.25   4  30.0  0.60   4  0.33  [1, 0, 0]
# 15   0.58   1   0.0  0.92   1  0.33  [0, 1, 0]
# 16   0.58   3   0.0  0.92   3  0.33  [0, 1, 0]
# 17   0.58   4   0.0  0.92   4  0.34  [0, 1, 0]
# 18   0.25   2  30.0  0.61   2  0.34  [1, 0, 0]
# ...

# %%
#Data shuffling. Shuffles the data to avoid biases.
data = data.iloc[np.random.permutation(len(data))]

# %%
data
# Out:
#        f1  f2    f3    f4  f5    f6         f7
# 396  0.75   4   0.0  0.11   5  0.36  [0, 0, 1]
# 73   0.58   4   0.0  0.92   4  0.33  [0, 1, 0]
# 132  0.25   4  30.0  0.61   4  0.34  [1, 0, 0]
# 178  0.92   2   0.0  0.25   3  0.34  [0, 1, 0]
# 200  0.25   4  30.0  0.59   4  0.32  [1, 0, 0]
# 190  0.25   4  30.0  0.59   4  0.32  [1, 0, 0]
# 101  0.58   3   0.0  0.92   3  0.34  [0, 1, 0]
# 348  0.25   1  30.0  0.60   1  0.33  [1, 0, 0]
# 320  0.58   3   0.0  0.93   3  0.35  [0, 1, 0]
# 352  0.58   2   0.0  0.92   2  0.34  [0, 1, 0]
# 92   0.25   1  30.0  0.59   1  0.32  [1, 0, 0]
# 27   0.25   3  30.0  0.59   3  0.32  [1, 0, 0]
# 269  0.25   5  30.0  0.58   5  0.31  [0, 1, 0]
# 93   0.25   4  30.0  0.61   4  0.33  [1, 0, 0]
# 125  0.58   4   0.0  0.92   4  0.33  [1, 0, 0]
# 232  0.25   1  30.0  0.61   1  0.34  [1, 0, 0]
# 359  0.25   4  30.0  0.61   4  0.34  [1, 0, 0]
# 144  0.25   3  30.0  0.59   3  0.32  [1, 0, 0]
# 112  0.58   1   0.0  0.92   1  0.33  [0, 1, 0]
# ...

# %%
#Reset the indexing.
data = data.reset_index(drop = True)

# %%
data
# Out:
#        f1  f2    f3    f4  f5    f6         f7
# 0    0.75   4   0.0  0.11   5  0.36  [0, 0, 1]
# 1    0.58   4   0.0  0.92   4  0.33  [0, 1, 0]
# 2    0.25   4  30.0  0.61   4  0.34  [1, 0, 0]
# 3    0.92   2   0.0  0.25   3  0.34  [0, 1, 0]
# 4    0.25   4  30.0  0.59   4  0.32  [1, 0, 0]
# 5    0.25   4  30.0  0.59   4  0.32  [1, 0, 0]
# 6    0.58   3   0.0  0.92   3  0.34  [0, 1, 0]
# 7    0.25   1  30.0  0.60   1  0.33  [1, 0, 0]
# 8    0.58   3   0.0  0.93   3  0.35  [0, 1, 0]
# 9    0.58   2   0.0  0.92   2  0.34  [0, 1, 0]
# 10   0.25   1  30.0  0.59   1  0.32  [1, 0, 0]
# 11   0.25   3  30.0  0.59   3  0.32  [1, 0, 0]
# 12   0.25   5  30.0  0.58   5  0.31  [0, 1, 0]
# 13   0.25   4  30.0  0.61   4  0.33  [1, 0, 0]
# 14   0.58   4   0.0  0.92   4  0.33  [1, 0, 0]
# 15   0.25   1  30.0  0.61   1  0.34  [1, 0, 0]
# 16   0.25   4  30.0  0.61   4  0.34  [1, 0, 0]
# 17   0.25   3  30.0  0.59   3  0.32  [1, 0, 0]
# 18   0.58   1   0.0  0.92   1  0.33  [0, 1, 0]
# ...

# %%
#Divide the dataset into training and test.

#Training set.
x_input = data.loc[0:305, ['f1','f2','f3','f4','f5','f6']]
temp = data['f7']
y_input = temp[0:306]

#Testing data.
x_test = data.loc[306:405, ['f1','f2','f3','f4','f5','f6']]
y_test = temp[306:406]

# %%
#Placeholders & variables. 6 features as input and 3 awards as output.
x = tf.placeholder(tf.float32, shape = [None, 6])
y_ = tf.placeholder(tf.float32, shape = [None, 3])

#Weight and Biases. It is used for softmax regression (parameters).
W = tf.Variable(tf.zeros([6, 3]))
b = tf.Variable(tf.zeros([3]))

# %%
#Softmax regression (model)
y = tf.nn.softmax(tf.matmul(x, W) + b)

# %%
#Loss function
#Measuring the performance of our softmax regression model.
cross_entropy = tf.reduce_mean(-tf.reduce_sum(y_ * tf.log(y), reduction_indices = [1]))

# %%
#Optimizer that implements Adam algorithm. (Adam is good for deep-learning task)
train_step = tf.train.AdamOptimizer(0.01).minimize(cross_entropy)

#Calculating the model's accuracy
correct_prediction = tf.equal(tf.argmax(y, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
#Session parameters
sess = tf.InteractiveSession()

#Initializing variables
init = tf.global_variables_initializer()
sess.run(init)

#Number of iterations
epoch = 2000

# %%
for step in xrange(epoch):
   _, c=sess.run([train_step,cross_entropy], feed_dict={x: x_input, y_:[t for t in y_input.as_matrix()]})
   if step%500==0 :
       print c
# Out:
# 1.09861
# 0.362997
# 0.351189
# 0.344664

# %%
#Random testing @ 307-404 (the data we separate from training)
a = data.loc[402, ['f1','f2','f3','f4','f5','f6']]
b = a.values.reshape(1, 6)
largest = sess.run(tf.argmax(y, 1), feed_dict = {x: b})[0]
if largest == 0:
    print "Prediction: Overtime Rate OT15"
elif largest == 1:
    print "Prediction: Overtime Rate OT20"
else :
    print "Prediction: Overtime Rate Weekend Multiplier"
# Out:
# Prediction: Overtime Rate OT15

# %%
#Calculate the accuracy of the model.
print sess.run(accuracy, feed_dict = {x: x_test, y_: [t for t in y_test.as_matrix()]})
# Out:
# 0.858586

# %%
#Manual checking if the learner prediction is correct. (datapoints 307 - 404)
data
# Out:
#        f1  f2    f3    f4  f5    f6         f7
# 0    0.75   4   0.0  0.11   5  0.36  [0, 0, 1]
# 1    0.58   4   0.0  0.92   4  0.33  [0, 1, 0]
# 2    0.25   4  30.0  0.61   4  0.34  [1, 0, 0]
# 3    0.92   2   0.0  0.25   3  0.34  [0, 1, 0]
# 4    0.25   4  30.0  0.59   4  0.32  [1, 0, 0]
# 5    0.25   4  30.0  0.59   4  0.32  [1, 0, 0]
# 6    0.58   3   0.0  0.92   3  0.34  [0, 1, 0]
# 7    0.25   1  30.0  0.60   1  0.33  [1, 0, 0]
# 8    0.58   3   0.0  0.93   3  0.35  [0, 1, 0]
# 9    0.58   2   0.0  0.92   2  0.34  [0, 1, 0]
# 10   0.25   1  30.0  0.59   1  0.32  [1, 0, 0]
# 11   0.25   3  30.0  0.59   3  0.32  [1, 0, 0]
# 12   0.25   5  30.0  0.58   5  0.31  [0, 1, 0]
# 13   0.25   4  30.0  0.61   4  0.33  [1, 0, 0]
# 14   0.58   4   0.0  0.92   4  0.33  [1, 0, 0]
# 15   0.25   1  30.0  0.61   1  0.34  [1, 0, 0]
# 16   0.25   4  30.0  0.61   4  0.34  [1, 0, 0]
# 17   0.25   3  30.0  0.59   3  0.32  [1, 0, 0]
# 18   0.58   1   0.0  0.92   1  0.33  [0, 1, 0]
# ...
